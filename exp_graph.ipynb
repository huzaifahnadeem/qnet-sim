# %%
import pandas as pd
import numpy as np
import os
import json
from collections import Counter
import matplotlib.pyplot as plt

# %%
# data_dir = './experiments-results/'

# data_dir = './experiments-results/good-res-slmp-seed-0-100'
# data_dir = './experiments-results/good-res-slmp-seed-100-200'
# data_dir = './experiments-results/good-res-slmp-seed-0-200-combined'


data_dir = './experiments-results/64-degrees'


# data_dir = '/home/hun13/qnet-sim/src/experiments-results/jun11-2024/slmp-rep-0-100'
# data_dir = '/home/hun13/qnet-sim/src/experiments-results/jun11-2024/slmp-rep-100-200'
# data_dir = '/home/hun13/qnet-sim/src/experiments-results/jun11-2024/slmp-rep-0-200'

filenames = os.listdir(data_dir)
filenames[:] = [x for x in filenames if x[-5:] == '.json'] # only select .json files

# %%
results = {}
for fn in filenames:
    with open(f'{data_dir}/{fn}', 'r') as jsonfile:
        results[fn] = json.load(jsonfile)

# %%
d = {
    'seed': [],
    'p': [],
    'q': [],
    'ts': [],
    'e2e_ebits': [],
    'x_dist': [],
    # 'y_dist': [],
}

for k in results.keys():
    seed = results[k]['params_used']['seed']
    p = results[k]['params_used']['qc_p_loss_init']
    q = results[k]['params_used']['prob_swap_loss']
    # xdist = results[k]['params_used']['x_dist_gte']

    ts_with_ebits = list(Counter(results[k]['results']['time_slot']).keys())
    e2e_per_ts = list(Counter(results[k]['results']['time_slot']).values())
    for idx, ts in enumerate(ts_with_ebits):
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --1 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(e2e_per_ts[idx])
    
    zero_ebits_ts = []
    for ts in range(2, results[k]['params_used']['num_ts'] + 1):
        if ts not in results[k]['results']['time_slot']:
            zero_ebits_ts.append(ts)

    for ts in zero_ebits_ts:
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --2 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(0)

df = pd.DataFrame(data=d)

# %%
df
# Out:
#       seed    p    q  ts  e2e_ebits  x_dist
# 0       28  0.4  0.0   2          2       1
# 1       28  0.4  0.0   3          1       2
# 2       28  0.4  0.0   4          1       3
# 3       28  0.4  0.0   7          1       6
# 4       28  0.4  0.0   8          2       7
# ...    ...  ...  ...  ..        ...     ...
# 2075    35  0.4  0.1   7          0       6
# 2076    35  0.4  0.1   8          0       7
# 2077    35  0.4  0.1   9          0       8
# 2078    35  0.4  0.1  10          0       9
# 2079    35  0.4  0.1  11          0      10
#
# [2080 rows x 6 columns]

# %%
# p,q = 0.55, 0 
# p,q = 0.4, 0 
# p,q = 0.4, 0.1  
x = 8
df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['seed'].describe()
# Out:
# count    69.000000
# mean     34.521739
# std      20.840860
# min       0.000000
# 25%      17.000000
# 50%      34.000000
# 75%      51.000000
# max      72.000000
# Name: seed, dtype: float64

# %%
data = {
    'p': [],
    'q': [],
    'ebit_per_cycle': [],
    'ebit_per_cycle_stdev': [],
    'x_dist': []
}

# ps = [0.4, 0.55, 0.7]
# qs = [0, 0.1, 0.5]
xs = range(1, 11)
pqs = [(0.55, 0), (0.4, 0.1), (0.4, 0)]

for p, q in pqs:
    for x in xs:
        val = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].mean()
        stdev = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].std()
        data['ebit_per_cycle'].append(np.log10(val))
        data['ebit_per_cycle_stdev'].append(stdev)
        data['p'].append(p)
        data['q'].append(q)
        data['x_dist'].append(x)

plotdf = pd.DataFrame(data=data)
# Out:
# /tmp/ipykernel_14842/1203134759.py:18: RuntimeWarning: divide by zero encountered in log10
#   data['ebit_per_cycle'].append(np.log10(val))

# %%
def set_size(w, h, ax=None): # from https://stackoverflow.com/questions/44970010/axes-class-set-explicitly-size-width-height-of-axes-in-given-units
    """ w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)

# %%
_, ax = plt.subplots()
# set_size(15, 15)
legend = []

p = 0.55
q = 0
legend.append(f"p={round(1-p, 2)}, q={1-q}")
color = 'green'
# plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', yerr = 'ebit_per_cycle_stdev', logy=False, c=color, ax=ax) # with error bars
plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', logy=False, c=color, ax=ax) # without error bars

p = 0.4
q = 0.1
legend.append(f"p={1-p}, q={1-q}")
color = 'orange'
# plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', yerr = 'ebit_per_cycle_stdev', logy=False, c=color, ax=ax) # with error bars
plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', logy=False, c=color, ax=ax) # without error bars

p = 0.4
q = 0
color = 'red'
legend.append(f"p={1-p}, q={1-q}")
# plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', yerr = 'ebit_per_cycle_stdev', logy=False, c=color, ax=ax) # with error bars
plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', logy=False, c=color, ax=ax) # without error bars

ax.legend(legend)
ax.grid()
ax.set_xlabel('X separation (hops)')
ax.set_ylabel('log10( ebits/timeslot )')
# Out:
# Text(0, 0.5, 'log10( ebits/timeslot )')

# %%
# plotdf['x_dist'].count()
p,q = 0.55, 0 
x = 8
plotdf.loc[(plotdf['x_dist'] == x) & (plotdf['p'] == p) & (plotdf['q'] == q)].describe()
# Out:
# /home/hun13/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           p    q  ebit_per_cycle  ebit_per_cycle_stdev  x_dist
# count  1.00  1.0             1.0                   1.0     1.0
# mean   0.55  0.0            -inf                   0.0     8.0
# std     NaN  NaN             NaN                   NaN     NaN
# min    0.55  0.0            -inf                   0.0     8.0
# 25%    0.55  0.0             NaN                   0.0     8.0
# 50%    0.55  0.0             NaN                   0.0     8.0
# 75%    0.55  0.0             NaN                   0.0     8.0
# max    0.55  0.0            -inf                   0.0     8.0

# %%
# _, ax = plt.subplots()
legend = []

# green
p = 0.55
q = 0
legend.append(f"p={round(1-p, 2)}, q={1-q}")
color = 'green'
x = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['x_dist']
y = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['ebit_per_cycle']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color=color)

# orange
p = 0.4
q = 0.1
legend.append(f"p={1-p}, q={1-q}")
color = 'orange'
x = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['x_dist']
y = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['ebit_per_cycle']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color=color)

# red
p = 0.4
q = 0
color = 'red'
legend.append(f"p={1-p}, q={1-q}")
x = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['x_dist']
y = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['ebit_per_cycle']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color=color)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       9 x = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['x_dist']
#      10 y = plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)]['ebit_per_cycle']
# ---> 11 m, b = np.polyfit(x, y, 1)
#      12 plt.plot(x, m*x + b, color=color)
#      14 # # orange
#      15 # p = 0.4
#      16 # q = 0.1
#    (...)
#      31 # m, b = np.polyfit(x, y, 1)
#      32 # plt.plot(x, m*x + b, color=color)
#
# File ~/.local/lib/python3.9/site-packages/numpy/lib/polynomial.py:639, in polyfit(x, y, deg, rcond, full, w, cov)
#     637     raise TypeError("expected 1D vector for x")
#     638 if x.size == 0:
# --> 639     raise TypeError("expected non-empty vector for x")
#     640 if y.ndim < 1 or y.ndim > 2:
#     641     raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
# varying lengths:

# data_dir = './experiments-results/varying-lengths-0.5-1-onesided'
# data_dir = '/home/hun13/qnet-sim/src/experiments-results/jun11-2024/varying-lengths-0.5-1-onesided'
data_dir = '/home/hun13/qnet-sim/src/experiments-results/jun11-2024/varying-lengths-0.5-1-twosided'

filenames = os.listdir(data_dir)
filenames[:] = [x for x in filenames if x[-5:] == '.json'] # only select .json files

# %%
results = {}
for fn in filenames:
    with open(f'{data_dir}/{fn}', 'r') as jsonfile:
        results[fn] = json.load(jsonfile)

# %%
d = {
    'seed': [],
    'p': [],
    'q': [],
    'ts': [],
    'e2e_ebits': [],
    'x_dist': [],
    # 'y_dist': [],
}

for k in results.keys():
    seed = results[k]['params_used']['seed']
    p = results[k]['params_used']['qc_p_loss_init']
    q = results[k]['params_used']['prob_swap_loss']
    # xdist = results[k]['params_used']['x_dist_gte']

    ts_with_ebits = list(Counter(results[k]['results']['time_slot']).keys())
    e2e_per_ts = list(Counter(results[k]['results']['time_slot']).values())
    for idx, ts in enumerate(ts_with_ebits):
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --1 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(e2e_per_ts[idx])
    
    zero_ebits_ts = []
    for ts in range(2, results[k]['params_used']['num_ts'] + 1):
        if ts not in results[k]['results']['time_slot']:
            zero_ebits_ts.append(ts)

    for ts in zero_ebits_ts:
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --2 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(0)

df = pd.DataFrame(data=d)

# %%
df
# Out:
#      seed    p    q  ts  e2e_ebits  x_dist
# 0      88  0.0  0.0   2          4       1
# 1      88  0.0  0.0   3          4       2
# 2      88  0.0  0.0   4          4       3
# 3      88  0.0  0.0   5          4       4
# 4      88  0.0  0.0   6          4       5
# ..    ...  ...  ...  ..        ...     ...
# 995    25  0.0  0.0   7          4       6
# 996    25  0.0  0.0   8          4       7
# 997    25  0.0  0.0   9          4       8
# 998    25  0.0  0.0  10          4       9
# 999    25  0.0  0.0  11          4      10
#
# [1000 rows x 6 columns]

# %%
data = {
    'p': [],
    'q': [],
    'ebit_per_cycle': [],
    'ebit_per_cycle_stdev': [],
    'x_dist': []
}

xs = range(1, 11)
pqs = [(0, 0)]

for p, q in pqs:
    for x in xs:
        val = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].mean()
        stdev = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].std()
        # data['ebit_per_cycle'].append(np.log10(val))
        data['ebit_per_cycle'].append(val)
        data['ebit_per_cycle_stdev'].append(stdev)
        data['p'].append(p)
        data['q'].append(q)
        data['x_dist'].append(x)

plotdf = pd.DataFrame(data=data)

# %%
plotdf
# Out:
#    p  q  ebit_per_cycle  ebit_per_cycle_stdev  x_dist
# 0  0  0            4.00              0.000000       1
# 1  0  0            3.99              0.100000       2
# 2  0  0            3.98              0.140705       3
# 3  0  0            3.98              0.140705       4
# 4  0  0            4.00              0.000000       5
# 5  0  0            4.00              0.000000       6
# 6  0  0            4.00              0.000000       7
# 7  0  0            3.99              0.100000       8
# 8  0  0            3.96              0.196946       9
# 9  0  0            3.99              0.100000      10

# %%
_, ax = plt.subplots()
legend = []


p = 0
q = 0
color = 'brown'
legend.append(f"p={1-p}, q={1-q}")
# plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', yerr = 'ebit_per_cycle_stdev', logy=False, c=color, ax=ax) # with error bars
plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', logy=False, c=color, ax=ax) # without error bars

ax.legend(legend)
ax.grid()
ax.set_xlabel('X separation (hops)')
# ax.set_ylabel('log10( ebits/timeslot )')
ax.set_ylabel('ebits/timeslot')
# Out:
# Text(0, 0.5, 'ebits/timeslot')

# %%
data_dir = './experiments-results/no_loss'

filenames = os.listdir(data_dir)
filenames[:] = [x for x in filenames if x[-5:] == '.json'] # only select .json files

results = {}
for fn in filenames:
    with open(f'{data_dir}/{fn}', 'r') as jsonfile:
        results[fn] = json.load(jsonfile)




d = {
    'seed': [],
    'p': [],
    'q': [],
    'ts': [],
    'e2e_ebits': [],
    'x_dist': [],
    # 'y_dist': [],
}

for k in results.keys():
    seed = results[k]['params_used']['seed']
    p = results[k]['params_used']['qc_p_loss_init']
    q = results[k]['params_used']['prob_swap_loss']
    # xdist = results[k]['params_used']['x_dist_gte']

    ts_with_ebits = list(Counter(results[k]['results']['time_slot']).keys())
    e2e_per_ts = list(Counter(results[k]['results']['time_slot']).values())
    for idx, ts in enumerate(ts_with_ebits):
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --1 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(e2e_per_ts[idx])
    
    zero_ebits_ts = []
    for ts in range(2, results[k]['params_used']['num_ts'] + 1):
        if ts not in results[k]['results']['time_slot']:
            zero_ebits_ts.append(ts)

    for ts in zero_ebits_ts:
        d['seed'].append(seed)
        d['p'].append(p)
        d['q'].append(q)
        xdist = int(ts - 1) # NOTE: --2 out of 2-- hacky way -- only applicable to this data where dist = ts-1.
        d['x_dist'].append(xdist)
        d['ts'].append(ts)
        d['e2e_ebits'].append(0)

df = pd.DataFrame(data=d)





data = {
    'p': [],
    'q': [],
    'ebit_per_cycle': [],
    'ebit_per_cycle_stdev': [],
    'x_dist': []
}

xs = range(1, 11)
pqs = [(0, 0)]

for p, q in pqs:
    for x in xs:
        val = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].mean()
        stdev = df.loc[(df['p'] == p) & (df['q'] == q) & (df['x_dist'] == x)]['e2e_ebits'].std()
        # data['ebit_per_cycle'].append(np.log10(val))
        data['ebit_per_cycle'].append(val)
        data['ebit_per_cycle_stdev'].append(stdev)
        data['p'].append(p)
        data['q'].append(q)
        data['x_dist'].append(x)

plotdf = pd.DataFrame(data=data)




_, ax = plt.subplots()
legend = []


p = 0
q = 0
color = 'brown'
legend.append(f"p={1-p}, q={1-q}")
# plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', yerr = 'ebit_per_cycle_stdev', logy=False, c=color, ax=ax) # with error bars
plotdf.loc[(plotdf['p'] == p) & (plotdf['q'] == q)].plot(x='x_dist', y='ebit_per_cycle', logy=False, c=color, ax=ax) # without error bars

ax.legend(legend)
ax.grid()
ax.set_xlabel('X separation (hops)')
# ax.set_ylabel('log10( ebits/timeslot )')
ax.set_ylabel('ebits/timeslot')
# Out:
# Text(0, 0.5, 'ebits/timeslot')

# %%
def length_prob_loss(p_loss_init, p_loss_length, length_km):
    prob_loss = 1 - (1 - p_loss_init) * np.power(10, - length_km * p_loss_length / 10)
    return prob_loss

# %%
def prob_loss_length_graph(p_loss_length, p_loss_init=0):
    lengths = [l/10.0 for l in range(0, 1000)]

    y_data = []
    x_data = []
    for km in lengths:
        y_data.append(length_prob_loss(p_loss_init=p_loss_init, p_loss_length=p_loss_length, length_km=km))
        x_data.append(km)

    fig = plt.figure()
    plt.plot(x_data, y_data)
    fig.suptitle(f'prob_loss over length function with p_loss_length={p_loss_length}')
    plt.xlabel('distance in km')
    plt.ylabel('prob of loss')

# %%
prob_loss_length_graph(0.25)
prob_loss_length_graph(0.25, p_loss_init=0.4)
prob_loss_length_graph(0.5)
prob_loss_length_graph(0.9)
prob_loss_length_graph(0.2)
prob_loss_length_graph(0, p_loss_init=0.25)
